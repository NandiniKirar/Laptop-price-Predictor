# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram'].astype('int32')
df['Weight'] = df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), object(8)
# memory usage: 107.0+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %%
sns.scatterplot(x=df['Inches'], y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df['TouchScreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(10)
# Out:
#      Company            TypeName  Inches  \
# 1056      HP            Notebook    15.6
# 799     Dell            Notebook    15.6
# 962     Acer            Notebook    15.6
# 1125  Lenovo  2 in 1 Convertible    14.0
# 229       HP            Notebook    15.6
# 684   Lenovo  2 in 1 Convertible    13.3
# 603      MSI              Gaming    17.3
# 1170      HP            Notebook    15.6
# 1236      HP           Ultrabook    14.0
# 1065    Dell           Ultrabook    13.3
#
#                                ScreenResolution                          Cpu  \
# 1056                                   1366x768   Intel Core i5 7200U 2.5GHz
# 799                           Full HD 1920x1080     Intel Core i3 6006U 2GHz
# 962                           Full HD 1920x1080   Intel Core i5 7200U 2.5GHz
# 1125  IPS Panel Full HD / Touchscreen 1920x1080   Intel Core i7 6500U 2.5GHz
# 229                           Full HD 1920x1080   Intel Core i7 7500U 2.7GHz
# ...

# %%
df['TouchScreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TouchScreen'>

# %%
sns.barplot(x=df['TouchScreen'],y=df['Price'])
# Out:
# <Axes: xlabel='TouchScreen', ylabel='Price'>

# %%
df['Ips'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ips'>

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#        Company   TypeName  Inches                  ScreenResolution  \
# 1028      Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 7        Apple  Ultrabook    13.3                          1440x900
# 913         HP   Notebook    15.6                 Full HD 1920x1080
# 1113        HP  Ultrabook    13.3                 Full HD 1920x1080
# 556   Mediacom   Notebook    13.3       IPS Panel Full HD 1920x1080
#
#                               Cpu Ram               Memory  \
# 1028   Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 7            Intel Core i5 1.8GHz   8  256GB Flash Storage
# 913    Intel Core i7 7500U 2.7GHz   8            256GB SSD
# 1113   Intel Core i7 6500U 2.5GHz   8            512GB SSD
# 556   Intel Atom x5-Z8350 1.44GHz   4   32GB Flash Storage
#
#                          Gpu       OpSys  Weight        Price  TouchScreen  \
# 1028   Intel HD Graphics 620  Windows 10    1.29   86526.7200            1
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  TouchScreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int64(4), object(8)
# ...

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.068197
# Weight         0.210370
# Price          1.000000
# TouchScreen    0.191226
# Ips            0.191226
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                         Cpu Ram  \
# 0   Apple  Ultrabook    13.3        Intel Core i5 2.3GHz   8
# 1   Apple  Ultrabook    13.3        Intel Core i5 1.8GHz   8
# 2      HP   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8
# 3   Apple  Ultrabook    15.4        Intel Core i7 2.7GHz  16
# 4   Apple  Ultrabook    13.3        Intel Core i5 3.1GHz   8
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS    1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS    1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS    1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS    1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  Ips  X_res  Y_res
# 0   71378.6832            0    0   2560   1600
# 1   47895.5232            0    0   1440    900
# ...

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    0

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    0
#
#         Cpu Name
# 0  Intel Core i5
# ...

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  TouchScreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    0
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    0
#
#         Cpu Name      Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook   8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook   8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook   8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook  16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook   8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  TouchScreen  Ips      Cpu brand
# 0  macOS    1.37   71378.6832            0    0  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  Intel Core i5
# 3  macOS    1.83  135195.3360            0    0  Intel Core i7
# 4  macOS    1.37   96095.8080            0    0  Intel Core i5

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
# Remove ".0" from floats
df['Memory'] = df['Memory'].astype(str).replace(r'\.0', '', regex=True)

# Convert GB/TB to numeric equivalents
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')  # 1TB = 1000GB

# Split into two parts based on '+'
new = df["Memory"].str.split("+", n=1, expand=True)

df["first"] = new[0].str.strip()
df["second"] = new[1].str.strip() if new.shape[1] > 1 else "0"

# Fill NaN values with "0"
df["second"] = df["second"].fillna("0")

# Store storage type presence before removing text
df["Layer1HDD"] = df["first"].str.contains("HDD", case=False).astype(int)
df["Layer1SSD"] = df["first"].str.contains("SSD", case=False).astype(int)
df["Layer1Hybrid"] = df["first"].str.contains("Hybrid", case=False).astype(int)
df["Layer1Flash_Storage"] = df["first"].str.contains("Flash Storage", case=False).astype(int)

df["Layer2HDD"] = df["second"].str.contains("HDD", case=False).astype(int)
df["Layer2SSD"] = df["second"].str.contains("SSD", case=False).astype(int)
df["Layer2Hybrid"] = df["second"].str.contains("Hybrid", case=False).astype(int)
df["Layer2Flash_Storage"] = df["second"].str.contains("Flash Storage", case=False).astype(int)

# Now remove all non-numeric characters to get just the size
df["first"] = df["first"].str.extract('(\d+)', expand=False).fillna("0").astype(int)
df["second"] = df["second"].str.extract('(\d+)', expand=False).fillna("0").astype(int)

# Final computation
df["HDD"] = (df["first"] * df["Layer1HDD"] + df["second"] * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"] + df["second"] * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"] + df["second"] * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"] + df["second"] * df["Layer2Flash_Storage"])

# Drop unnecessary columns
df.drop(columns=[
    'first', 'second',
    'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
    'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'
], inplace=True)
# Out:
# <>:29: SyntaxWarning: invalid escape sequence '\d'
# <>:30: SyntaxWarning: invalid escape sequence '\d'
# <>:29: SyntaxWarning: invalid escape sequence '\d'
# <>:30: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\481346469.py:29: SyntaxWarning: invalid escape sequence '\d'
#   df["first"] = df["first"].str.extract('(\d+)', expand=False).fillna("0").astype(int)
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\481346469.py:30: SyntaxWarning: invalid escape sequence '\d'
#   df["second"] = df["second"].str.extract('(\d+)', expand=False).fillna("0").astype(int)

# %%
df.sample(5)
# Out:
#       Company  TypeName Ram               Memory                      Gpu  \
# 260      Dell  Notebook   8  128 SSD +  1000 HDD           AMD Radeon 530
# 1231    Razer    Gaming  16             1000 SSD  Nvidia GeForce GTX 1060
# 668   Toshiba  Notebook   8              256 SSD    Intel HD Graphics 620
# 588    Lenovo  Notebook  12             1000 HDD    Intel HD Graphics 620
# 258       MSI    Gaming  16  512 SSD +  1000 HDD  Nvidia GeForce GTX 1070
#
#            OpSys  Weight      Price  TouchScreen  Ips      Cpu brand   HDD  \
# 260   Windows 10    2.80   60845.76            0    0  Intel Core i7  1000
# 1231  Windows 10    1.95  186426.72            0    0  Intel Core i7     0
# 668   Windows 10    2.00   67026.24            0    0  Intel Core i5     0
# 588   Windows 10    2.20   32447.52            1    1  Intel Core i7  1000
# 258   Windows 10    4.14  133146.72            0    0  Intel Core i7  1000
#
#        SSD  Hybrid  Flash_Storage
# 260    128       0              0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook   8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook   8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook   8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook  16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook   8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  Ips      Cpu brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    0  Intel Core i5    0  128       0
# 1   47895.5232            0    0  Intel Core i5    0    0       0
# 2   30636.0000            0    0  Intel Core i5    0  256       0
# 3  135195.3360            0    0  Intel Core i7    0  512       0
# 4   96095.8080            0    0  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# 2              0
# 3              0
# 4              0

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Weight           0.210370
# Price            1.000000
# TouchScreen      0.191226
# Ips              0.191226
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook   8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook   8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook   8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook  16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook   8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  TouchScreen  Ips      Cpu brand  HDD  SSD
# 0   71378.6832            0    0  Intel Core i5    0  128
# 1   47895.5232            0    0  Intel Core i5    0    0
# 2   30636.0000            0    0  Intel Core i5    0  256
# 3  135195.3360            0    0  Intel Core i7    0  512
# 4   96095.8080            0    0  Intel Core i5    0  256

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\1111925144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName Ram  OpSys  Weight        Price  TouchScreen  Ips  \
# 0   Apple  Ultrabook   8  macOS    1.37   71378.6832            0    0
# 1   Apple  Ultrabook   8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook   8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook  16  macOS    1.83  135195.3360            0    0
# 4   Apple  Ultrabook   8  macOS    1.37   96095.8080            0    0
#
#        Cpu brand  HDD  SSD Gpu brand
# 0  Intel Core i5    0  128     Intel
# 1  Intel Core i5    0    0     Intel
# 2  Intel Core i5    0  256     Intel
# 3  Intel Core i7    0  512       AMD
# 4  Intel Core i5    0  256     Intel

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)
# Out:
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\3648919379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName Ram  OpSys  Weight        Price  TouchScreen  Ips  \
# 0   Apple  Ultrabook   8  macOS    1.37   71378.6832            0    0
# 1   Apple  Ultrabook   8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook   8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook  16  macOS    1.83  135195.3360            0    0
# 4   Apple  Ultrabook   8  macOS    1.37   96095.8080            0    0
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'], inplace=True, errors='ignore')
# Out:
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\4045192651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'], inplace=True, errors='ignore')

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\3442460328.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Weight         0.209867
# Price          1.000000
# TouchScreen    0.192917
# Ips            0.192917
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
#Compute correlation only on numeric columns
corr_matrix = df.corr(numeric_only=True)

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\neshu\AppData\Local\Temp\ipykernel_30864\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName Ram  Weight  TouchScreen  Ips  \
# 0      Apple           Ultrabook   8    1.37            0    0
# 1      Apple           Ultrabook   8    1.34            0    0
# 2         HP            Notebook   8    1.86            0    0
# 3      Apple           Ultrabook  16    1.83            0    0
# 4      Apple           Ultrabook   8    1.37            0    0
# ...      ...                 ...  ..     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible   4    1.80            1    1
# 1299  Lenovo  2 in 1 Convertible  16    1.30            1    1
# 1300  Lenovo            Notebook   2    1.50            0    0
# 1301      HP            Notebook   6    2.19            0    0
# 1302    Asus            Notebook   4    2.20            0    0
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 0             Intel Core i5     0  128     Intel                 Mac
# 1             Intel Core i5     0    0     Intel                 Mac
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName Ram  Weight  TouchScreen  Ips  \
# 183   Toshiba            Notebook   8    2.00            0    0
# 1141      MSI              Gaming   8    2.40            0    0
# 1049     Asus             Netbook   4    1.20            0    0
# 1020     Dell  2 in 1 Convertible   4    2.08            1    1
# 878      Dell            Notebook   4    2.18            0    0
# ...       ...                 ...  ..     ...          ...  ...
# 466      Acer            Notebook   4    2.20            0    0
# 299      Asus           Ultrabook  16    1.63            0    0
# 493      Acer            Notebook   8    2.20            0    0
# 527    Lenovo            Notebook   8    2.20            0    0
# 1193    Apple           Ultrabook   8    0.92            0    0
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 183           Intel Core i5     0  128     Intel             Windows
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %%
print(X_train.columns.tolist())
# Out:
# ['Company', 'TypeName', 'Ram', 'Weight', 'TouchScreen', 'Ips', 'Cpu brand', 'HDD', 'SSD', 'Gpu brand', 'os']

# %%
categorical_cols = ['Company', 'TypeName', 'Cpu', 'Gpu', 'OpSys']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

#  Step 1: Check your feature columns
print(X_train.columns.tolist())


# Corrected ColumnTransformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse_output=False), ['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os'])  # use column **names**, not indexes
], remainder='passthrough')

# Linear Regression model
step2 = LinearRegression()

# Pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Train
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluation
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# ['Company', 'TypeName', 'Ram', 'Weight', 'TouchScreen', 'Ips', 'Cpu brand', 'HDD', 'SSD', 'Gpu brand', 'os']
# R2 score: 0.7820081874429838
# MAE: 0.216808418590716

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

# Step 1: Use column names instead of indexes
categorical_cols = ['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os']  # replace with exact column names

# Step 2: ColumnTransformer with OneHotEncoding
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse_output=False), categorical_cols)
], remainder='passthrough')

#Step 3: Ridge Regression
step2 = Ridge(alpha=10)

#Step 4: Pipeline
pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

#Step 5: Train
pipe.fit(X_train, y_train)

#Step 6: Predict
y_pred = pipe.predict(X_test)

#Step 7: Evaluation
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.7919525007325664
# MAE: 0.21224702974917156

# %% [markdown]
# ## Lasso Regresion

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score, mean_absolute_error

# ✔ Corrected column names
categorical_cols = ['Company', 'TypeName', 'Gpu brand', 'Cpu brand', 'os']
numerical_cols = ['Ram', 'Weight', 'TouchScreen', 'Ips', 'HDD', 'SSD']

# Preprocessing
preprocessor = ColumnTransformer([
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
])

# Pipeline
pipe = Pipeline([
    ('pre', preprocessor),
    ('model', Lasso(alpha=0.001))
])

# Fit
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.783351238456647
# MAE: 0.21682026027160978

# %% [markdown]
# ## KNN

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# Step 1: Correct columns
categorical_cols = ['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight']

# Step 2: Preprocessing
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
], remainder='passthrough')  # Keep: Touchscreen, Ips, HDD, SSD

# Step 3: Model
model = KNeighborsRegressor(n_neighbors=3)

# Step 4: Pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

# Step 5: Fit
pipe.fit(X_train, y_train)

# Step 6: Predict
y_pred = pipe.predict(X_test)

# Step 7: Evaluation
print('R2 Score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.8275737672272121
# MAE: 0.18649074000249166

# %%
## decision tree

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# Step 1: Specify correct column names
categorical_cols = ['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight']

# Step 2: Create preprocessor
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
], remainder='passthrough')  # Keep Touchscreen, Ips, HDD, SSD

# Step 3: Create model
model = DecisionTreeRegressor(max_depth=8, random_state=42)

# Step 4: Create pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

# Step 5: Fit
pipe.fit(X_train, y_train)

# Step 6: Predict
y_pred = pipe.predict(X_test)

# Step 7: Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.8628088865114987
# MAE: 0.17222529314774254

# %%
## SVM

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVR
from sklearn.metrics import r2_score, mean_absolute_error

# Step 1: Correct column names (replace these with your actual DataFrame column names)
categorical_cols = ['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight']

# Step 2: Preprocessor
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
], remainder='passthrough')

# Step 3: SVR model
model = SVR(kernel='rbf', C=10000, epsilon=0.1)

# Step 4: Pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

# Step 5: Train
pipe.fit(X_train, y_train)

# Step 6: Predict
y_pred = pipe.predict(X_test)

# Step 7: Evaluate
print("R2 score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8257914626633331
# MAE: 0.19631152344261324

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# Step 1: Actual column names (replace these with your dataset's correct column names)
categorical_cols = ['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight']

# Step 2: Preprocessing pipeline
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
], remainder='passthrough')

# Step 3: Model
model = RandomForestRegressor(
    n_estimators=100,
    random_state=3,
    max_samples=0.5,
    max_features=0.75,
    max_depth=15
)

# Step 4: Full pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

# Step 5: Fit the pipeline
pipe.fit(X_train, y_train)

# Step 6: Predict
y_pred = pipe.predict(X_test)

# Step 7: Evaluate
print("R2 score:",  r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8836029228237768
# MAE: 0.1608647196178066

# %%
## extra trees

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

categorical_cols = ['Company', 'TypeName', 'TouchScreen', 'Ips', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight', 'HDD', 'SSD']

# Preprocessing
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
])

# Model WITHOUT max_samples
model = ExtraTreesRegressor(
    n_estimators=100,
    random_state=3,
    max_features=0.75,
    max_depth=15
)

# Pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

# Fit
pipe.fit(X_train, y_train)

# Predict
y_pred = pipe.predict(X_test)

# Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.8564252776717913
# MAE: 0.17089691834817577

# %%
#Ada boost

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

# Categorical and numerical columns (based on your X_train)
categorical_cols = ['Company', 'TypeName', 'TouchScreen', 'Ips', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight', 'HDD', 'SSD']

#  Step 1: Preprocessing
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
])

#  Step 2: Model
model = AdaBoostRegressor(n_estimators=15, learning_rate=1.0)

# Step 3: Pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

# Step 4: Train
pipe.fit(X_train, y_train)

# Step 5: Predict
y_pred = pipe.predict(X_test)

# Step 6: Evaluation
print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.7900712953959826
# MAE: 0.23177133509562406

# %%
#Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

# Define columns properly
categorical_cols = ['Company', 'TypeName', 'TouchScreen', 'Ips', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight', 'HDD', 'SSD']

#  Step 1: Preprocessing
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
])

#  Step 2: Model
model = GradientBoostingRegressor(n_estimators=500)

#  Step 3: Pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

#  Step 4: Train
pipe.fit(X_train, y_train)

#  Step 5: Predict
y_pred = pipe.predict(X_test)

#  Step 6: Evaluate
print("R2 Score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score: 0.8863179238282787
# MAE: 0.16101158835831558

# %%
##XGBoost Regressor

# %%
from xgboost import XGBRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

# Define column names properly
categorical_cols = ['Company', 'TypeName', 'TouchScreen', 'Ips', 'Cpu brand', 'Gpu brand', 'os']
numerical_cols = ['Ram', 'Weight', 'HDD', 'SSD']

# Step 1: Preprocessing
preprocessor = ColumnTransformer(transformers=[
    ('cat', OneHotEncoder(drop='first', sparse_output=False), categorical_cols),
    ('num', StandardScaler(), numerical_cols)
])

#  Step 2: Model
model = XGBRegressor(n_estimators=45, max_depth=5, learning_rate=0.5)

#  Step 3: Pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', model)
])

#  Step 4: Fit
pipe.fit(X_train, y_train)

#  Step 5: Predict
y_pred = pipe.predict(X_test)

#  Step 6: Evaluate
print("R2 score:", r2_score(y_test, y_pred))
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8799459209663878
# MAE: 0.16233760991241

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, StackingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_absolute_error

# ✅ Step 1: Preprocessing
preprocessor = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(drop='first', sparse_output=False), 
     ['Company', 'TypeName', 'Cpu brand', 'Gpu brand', 'os'])
], remainder='passthrough')

# ✅ Step 2: Base estimators
estimators = [
    ('rf', RandomForestRegressor(
        n_estimators=350, 
        random_state=3,
        max_samples=0.5,
        max_features=0.75,
        max_depth=15,
        bootstrap=True  # 👈 necessary for using max_samples
    )),
    ('gbdt', GradientBoostingRegressor(n_estimators=100, max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25, learning_rate=0.3, max_depth=5))
]

# ✅ Step 3: Stacking Regressor
stacking_model = StackingRegressor(
    estimators=estimators,
    final_estimator=Ridge(alpha=100)
)

# ✅ Step 4: Pipeline
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', stacking_model)
])

# ✅ Step 5: Train
pipe.fit(X_train, y_train)

# ✅ Step 6: Predict
y_pred = pipe.predict(X_test)

# ✅ Step 7: Metrics
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8772435623547701
# MAE: 0.16745339536386145

# %%
#exporting model
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName Ram  Weight        Price  TouchScreen  Ips  \
# 0      Apple           Ultrabook   8    1.37   71378.6832            0    0
# 1      Apple           Ultrabook   8    1.34   47895.5232            0    0
# 2         HP            Notebook   8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook  16    1.83  135195.3360            0    0
# 4      Apple           Ultrabook   8    1.37   96095.8080            0    0
# ...      ...                 ...  ..     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible   4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible  16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook   2    1.50   12201.1200            0    0
# 1301      HP            Notebook   6    2.19   40705.9200            0    0
# 1302    Asus            Notebook   4    2.20   19660.3200            0    0
#
# ...

# %%
X_train
# Out:
#       Company            TypeName Ram  Weight  TouchScreen  Ips  \
# 183   Toshiba            Notebook   8    2.00            0    0
# 1141      MSI              Gaming   8    2.40            0    0
# 1049     Asus             Netbook   4    1.20            0    0
# 1020     Dell  2 in 1 Convertible   4    2.08            1    1
# 878      Dell            Notebook   4    2.18            0    0
# ...       ...                 ...  ..     ...          ...  ...
# 466      Acer            Notebook   4    2.20            0    0
# 299      Asus           Ultrabook  16    1.63            0    0
# 493      Acer            Notebook   8    2.20            0    0
# 527    Lenovo            Notebook   8    2.20            0    0
# 1193    Apple           Ultrabook   8    0.92            0    0
#
#                   Cpu brand   HDD  SSD Gpu brand                  os
# 183           Intel Core i5     0  128     Intel             Windows
# ...
